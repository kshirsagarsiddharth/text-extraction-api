# %%
from extraction import Preprocessing 
import matplotlib.pyplot as plt 
import cv2 
import pytesseract 
import re 
from scipy import ndimage 
import os 
import gc 
gc.collect()
# Out:
# 34

# %%
import os 

for image in os.listdir('images_dir'):
    path = os.path.join('images_dir',image)
    
    img_array = cv2.imread(path)
    newdata=pytesseract.image_to_osd(img_array)
    rotation = re.findall('Rotate:\s\d+', newdata)[0]
    print(rotation)
    degrees = 360 - int(rotation.split()[-1])
    plt.figure(figsize = (12,8))
    plt.imshow(ndimage.rotate(img_array, degrees))
    plt.show()

# %%
newdata=pytesseract.image_to_osd(img_array)
rotation = re.findall('Rotate:\s\d+', newdata)[0]
degrees = 360 - int(rotation.split()[-1])
plt.figure(figsize = (12,8))
plt.imshow(ndimage.rotate(img_array, degrees))

# %%
 img_array = cv2.imread(path)

# %%
plt.figure(figsize=(12,8))
plt.imshow(img_array)

# %%
path = '/mnt/d/rest_apis_python/text_analyzer_api/code/images_dir/IMG_20211106_160648.jpg'
text = []
image_object = Preprocessing(path)
image_object.correct_orientation()
image_object.get_grayscale()
image_object.thresholding()
image_object.opening()
text.append(image_object.extract_text())
# Out:
# Rotate: 180
# 1
# ---------------------------------------------------------------------------
# TesseractError                            Traceback (most recent call last)
# /tmp/ipykernel_299/4068082082.py in <module>
#       7 image_object.opening()
#       8 print(1)
# ----> 9 text.append(image_object.extract_text())
#
# /mnt/d/rest_apis_python/text_analyzer_api/code/extraction.py in extract_text(self)
#      52
#      53     def extract_text(self):
# ---> 54         return pytesseract.image_to_string(self.image)
#      55
#      56
#
# /mnt/d/rest_apis_python/text_analyzer_api/venv/lib/python3.8/site-packages/pytesseract/pytesseract.py in image_to_string(image, lang, config, nice, output_type, timeout)
#     411     args = [image, 'txt', lang, config, nice, timeout]
#     412
# --> 413     return {
#     414         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     415         Output.DICT: lambda: {'text': run_and_get_output(*args)},
#
# ...

# %%
import boto3 
import io 
from PIL import Image as pil_image
import matplotlib.image as mpimg
import numpy as np 
s3 = boto3.resource('s3') 
BUCKET_NAME = 'image-analysis-bucket48549839'
bucket = s3.Bucket(BUCKET_NAME)
KEY = 'siddharth2-58871aba-3f28-11ec-8098-00155d8df94e-IMG_20211106_150856.jpg'
bucket_object = bucket.Object(KEY)
response = bucket_object.get()
file_stream = response['Body']

# %%
np.array(Image.open(file_stream))
# Out:
# array([[[227, 226, 222],
#         [224, 223, 219],
#         [224, 223, 219],
#         ...,
#         [185, 173, 157],
#         [186, 174, 158],
#         [188, 176, 160]],
#
#        [[225, 224, 220],
#         [224, 223, 219],
#         [224, 223, 219],
#         ...,
#         [167, 155, 139],
#         [169, 157, 141],
#         [173, 161, 145]],
#
#        [[229, 228, 224],
#         [228, 227, 223],
#         [228, 227, 223],
#         ...,
#         [166, 154, 138],
#         [166, 154, 138],
#         [168, 156, 140]],
#
#        ...,
#
#        [[165, 164, 159],
#         [168, 167, 162],
#         [182, 181, 176],
#         ...,
#         [102,  92,  67],
#         [102,  92,  67],
#         [101,  91,  66]],
#
#        [[204, 203, 198],
#         [204, 203, 198],
#         [207, 206, 201],
#         ...,
#         [103,  93,  68],
#         [100,  90,  65],
#         [100,  90,  65]],
#
#        [[234, 233, 228],
#         [230, 229, 224],
#         [222, 221, 216],
# ...
